# %% [markdown]
# <center><h2> **Graduate Rotational Internship Program @ THE SPARKS FOUNDATION**</h2></center>

# %% [markdown]
# <center><h2>Data Science And Business Analytics - Task3</h2></center>

# %% [markdown]
# ## **Name- Nitig Singh**
#  **Batch- JULY 2022**

# %% [markdown]
# # **TASK-3**
# ## **DATA ANALYSIS OF A BUSINESS PROBLEM**
# ### **EXPLORATORY DATA ANALYSIS-RETAIL**
# (LEVEL-BEGINNER)
#
#
# *   Perform an Exploratory Data Analysis on a Business Problem.
# *   A Superstore Data Set was given on which we need to perform Exploratory Data Analysis.
# *   Here, As a business manager, we are finding out the weak areas where we can work to make more profit.
# *   What all business problems we can derive by exploring the data?
# *   Used Python language, in Jupyter Notebook.
#
#
# ------------------------------------

# %% [markdown]
# ### To Do:
# #### Perform an Exploratory Data Analysis on a Superstore Data Set to definea  Business Problem.

# %%
# First of all we must import the libraries:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
import warnings as wg
wg.filterwarnings('ignore')
import os
#os.chdir(R"C:\Users\dell\Desktop\interns\tasks\t3")

# %%
supstr=pd.read_csv("SampleSuperstore.csv")
print("Data imported successfully")
# Out:
# Data imported successfully

# %%
supstr.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
supstr.shape
# Out:
# (9994, 13)

# %%
supstr.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
supstr.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
supstr.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ### We need to know:
#
# 1 ) Which features are available in the dataset?
# 2 ) Which features are categorical?
# 3 ) Which features are numerical?
# 4 ) What are the data types for various features?

# %% [markdown]
# **1 ) Which features are available in the dataset:**

# %%
print("Our dataset consist of {} samples".format(supstr.shape[0]))
print('-'*50)
print("There are {} features: {}".format(supstr.shape[1],supstr.columns.values))
print('-'*50)
# Out:
# Our dataset consist of 9994 samples
# --------------------------------------------------
# There are 13 features: ['Ship Mode' 'Segment' 'Country' 'City' 'State' 'Postal Code' 'Region'
#  'Category' 'Sub-Category' 'Sales' 'Quantity' 'Discount' 'Profit']
# --------------------------------------------------

# %%
supstr.drop_duplicates()
supstr.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# We can dispense with the postal code feature
supstr = supstr.drop("Postal Code", axis=1)

# %%
supstr.shape
# Out:
# (9994, 12)

# %%
supstr.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
print("features possible values are :\n\n")
print('Ship Mode :\n')
print(data['Ship Mode'].value_counts())
print('-'*100)
print('Segment :\n')
print(data['Segment'].value_counts())
print('-'*100)
print('Country :\n')
print(data['Country'].value_counts())
print('-'*100)
print('City :\n')
print(data['City'].value_counts())
print('-'*100)
print('State :\n')
print(data['State'].value_counts())
print('-'*100)
print('Region :\n')
print(data['Region'].value_counts())
print('-'*100)
print('Category :\n')
print(data['Category'].value_counts())
print('-'*100)
print('Sub-Category :\n')
print(data['Sub-Category'].value_counts())
print('-'*100)
print('Sales :\n')
print(data['Sales'].value_counts())
print('-'*100)
print('Quantity :\n')
print(data['Quantity'].value_counts())
print('-'*100)
print('Discount :\n')
print(data['Discount'].value_counts())
print('-'*100)
print('Profit :\n')
print(data['Profit'].value_counts())
print('-'*100)
# Out:
# features possible values are :
#
#
# Ship Mode :
#
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Segment :
#
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Country :
#
# United States    9994
# Name: Country, dtype: int64
# ----------------------------------------------------------------------------------------------------
# City :
#
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64
# ...

# %% [markdown]
# **2 ) Which features are categorical :**
#  - Ship Mode (Nominal)
#  - Segment (Nominal)
#  - Country (Nominal)
#  - City (Nominal)
#  - State (Nominal)
#  - Region (Nominal)
#  - Category (Nominal)
#  - Sub-Category (Nominal)

# %% [markdown]
# **3 ) Which features are numerical:**
#  - Sales (continuous)
#  - Quantity (Discrete)
#  - Discount (Continuous)
#  - Profit (Continuous)

# %% [markdown]
# **4 ) What are the data types for various features?**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # *Exploratory Data Analysis*

# %%
sns.pairplot(supstr)

# %%
# Finding the correlation between variables
corr_data=supstr.corr()
display(corr_data)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
supstr.corr()
plt.figure(figsize=(10,5))
sns.heatmap(supstr.corr(), annot=True)
plt.show()

# %% [markdown]
# From above Heatmap we can conclude that there is a Negative correlation between Profit and Discount whereas, a Positive correlation between Profit and Sales

# %% [markdown]
# ### Product Analysis

# %%
plt.figure(figsize=(6,6))
textprops = {'fontsize':15}
plt.title('Category')
plt.pie(supstr['Category'].value_counts(), labels=supstr['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
plt.figure(figsize = (10,16))
supstr.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.ylabel('Profit')
plt.title("PRODUCT CATEGORY WISE SALES AND PROFIT",fontdict={'color':'black','fontsize':20})
plt.show()

# %% [markdown]
# This Bar Plot shows that Technology has given maximum sales and subsequently Profit was also the highest. But in case of Furniture, though Sales is high, profit is the least

# %%
top_category_s = supstr.groupby('Category').Sales.sum().nlargest(n=100)
top_category_p = supstr.groupby('Category').Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
top_category_s.plot(kind='bar', figsize=(10,5), fontsize=14)
top_category_p.plot(kind='bar', figsize=(10,5), fontsize=14, color='red')
plt.xlabel('Category', fontsize=15)
plt.ylabel('Total Sales/Profits', fontsize=15)
plt.title('Top Category Sales vs Profit', fontsize=15)
plt.show()

# %% [markdown]
# *Computing top sub-categories in terms of sales and profit from first 100 observation and plotting them.*

# %%
#Since Furniture showed an unsual trend, now looking at sales and profit for subcategories of Furniture
sns.set(style='dark')
supstr[supstr['Category']=='Furniture'].groupby(['Sub-Category'])['Sales','Profit'].sum().plot.bar(color=['#4E232E','#ffd966'],figsize=(12,6))
plt.xlabel("SUB CATEGORY",fontdict={'color':'black','fontsize':15})
plt.title("SUB-CATEGORY WISE SALES AND PROFIT FOR FURNITURE",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'SUB-CATEGORY WISE SALES AND PROFIT FOR FURNITURE')

# %% [markdown]
# So we have sub categories of Furniture which are Bookcases,Chairs,Furnishings and Tables. With this Bar Plot we can conclude that irrespective of high sales in Tables and Bookcases the store is incurring loss. This loss is affecting the whole of Furniture Category

# %%
#Now we need to check irrespective of high sales why are we incurring loss?
#To check the probable reason of loss lets look at the discount given to each Furniture sub-category
sns.set(style='dark')
supstr[supstr['Category']=='Furniture'].groupby(['Sub-Category'])['Discount'].mean().plot.bar(color='#0000FF',figsize=(12,6))
plt.xlabel("SUB CATEGORY",fontdict={'color':'black','fontsize':15})
plt.title("DISCOUNT GIVEN IN FURNITURE CATEGORY",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'DISCOUNT GIVEN IN FURNITURE CATEGORY')

# %% [markdown]
# From the above bar plot we concluded that the maximum discount is given on Tables followed by Bookcases but, still the store is incurring losses from them.

# %%
top_subcategory_s = supstr.groupby('Sub-Category').Sales.sum().nlargest(n=100)
top_subcategory_p = supstr.groupby('Sub-Category').Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
top_subcategory_s.plot(kind='bar', figsize=(10,5), fontsize=14)
top_subcategory_p.plot(kind='bar', figsize=(10,5), fontsize=14, color='red')
plt.xlabel('Sub-Category', fontsize=15)
plt.ylabel('Total Sales/Profits', fontsize=15)
plt.title('Top Sub-Category Sales vs Profit', fontsize=15)
plt.show()

# %%
# Now we will check the Top Products Sold
sns.set(style='dark')
supstr.groupby(['Sub-Category'])['Sales'].sum().sort_values(ascending=False).plot.bar(color=['Yellow'],figsize=(12,6))
plt.xlabel("SUB CATEGORY",fontdict={'color':'black','fontsize':15})
plt.ylabel("SALES",fontdict={'color':'black','fontsize':15})
plt.title("SUB-CATEGORY WISE SALES",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'SUB-CATEGORY WISE SALES')

# %% [markdown]
# With this we concluded that Phones,Chairs ,Storage,Tables and Binders are being sold the most. Whereas Fasteners,Labels and Envelopes were sold the least

# %%
#To check the profit earned from all the Sub-Categories
sns.set(style='dark')
supstr.groupby(['Sub-Category'])['Profit'].sum().sort_values(ascending=False).plot.bar(color=['#F4A460'],figsize=(12,6))
plt.xlabel("SUB CATEGORY",fontdict={'color':'white','fontsize':15})
plt.ylabel("PROFIT",fontdict={'color':'black','fontsize':15})
plt.title("SUB-CATEGORY WISE PROFIT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'SUB-CATEGORY WISE PROFIT')

# %%
plt.figure(figsize=(14,12))
statewise = supstr.groupby(['Sub-Category'])['Profit'].sum().nlargest(50)
statewise.plot.barh()
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %%
plt.figure(figsize=(8,7))
sns.lineplot(supstr['Discount'], supstr['Profit'], data=supstr)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
plt.figure(figsize = (6,6))
plt.title('Region')
supstr['Region'].value_counts().plot.pie(colors=['r','g','b','y'], labels=supstr['Region'].value_counts().index,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Region'}, ylabel='Region'>

# %% [markdown]
# **The graph above shows that West and East have same profit though sales in the East are less as compared to West.**

# %%
#Next we will check what amount of sales and profits were being made by each Region
sns.set(style='dark')
Supstr.groupby(['Region'])['Sales','Profit'].sum().plot.bar(color=['#377F88','#DC143C'],figsize=(12,6))
plt.xlabel("REGION",fontdict={'color':'black','fontsize':15})
plt.title("REGION WISE SALES AND PROFIT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'REGION WISE SALES AND PROFIT')

# %% [markdown]
# From the bar plot we can see that West Region contributes maximum towards sales and profit

# %% [markdown]
# *Visualising the Sales vs Profits in different states*

# %%
#To check the sales earned from the top 5 cities
sns.set(style='dark')
supstr.groupby(['City'])['Sales'].sum().sort_values(ascending=False).head().plot.bar(color=['Pink'],figsize=(12,6))
plt.xlabel("CITY",fontdict={'color':'white','fontsize':15})
plt.ylabel("SALES",fontdict={'color':'black','fontsize':15})
plt.title("CITY WISE SALES",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'CITY WISE SALES')

# %%
#To check the sales earned from the top 5 cities
sns.set(style='dark')
supstr.groupby(['City'])['Sales'].sum().sort_values(ascending=False).head().plot.bar(color=['Pink'],figsize=(12,6))
plt.xlabel("CITY",fontdict={'color':'white','fontsize':15})
plt.ylabel("SALES",fontdict={'color':'black','fontsize':15})
plt.title("CITY WISE SALES",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'CITY WISE SALES')

# %% [markdown]
# New York City has the most sales followed by Los Angeles and Seattle

# %%
#To check the profit earned from the top 5 ciies
sns.set(style='dark')
supstr.groupby(['City'])['Profit'].sum().sort_values(ascending=False).head().plot.bar(color=['Green'],figsize=(12,6))
plt.xlabel("CITY",fontdict={'color':'white','fontsize':15})
plt.ylabel("PROFIT",fontdict={'color':'black','fontsize':15})
plt.title("CITY WISE PROFIT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'CITY WISE PROFIT')

# %% [markdown]
# Similarly most profit is earned from New York City followed by Los Angeles and Seattle.

# %%
#To check the discount given to the top 5 ciies
sns.set(style='dark')
supstr.groupby(['City'])['Discount'].sum().sort_values(ascending=False).head().plot.bar(color=['Red'],figsize=(12,6))
plt.xlabel("CITY",fontdict={'color':'white','fontsize':15})
plt.ylabel("DISCOUNT",fontdict={'color':'black','fontsize':15})
plt.title("CITY WISE DISCOUNT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'CITY WISE DISCOUNT')

# %% [markdown]
# Interestingly highest total discount is for Philadelphia followed by Houston and Chicago. But they do not lead the Sales and Profit table

# %%
#To check the 5 cities that are giving me loss
sns.set(style='dark')
supstr.groupby(['City'])['Profit'].sum().sort_values(ascending=False).tail().plot.bar(color=['Blue'],figsize=(12,6))
plt.xlabel("SUB CATEGORY",fontdict={'color':'white','fontsize':15})
plt.ylabel("PROFIT",fontdict={'color':'black','fontsize':15})
plt.title("CITIES GIVING LEAST PROFIT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'CITIES GIVING LEAST PROFIT')

# %% [markdown]
# Philadelphia followed by Houston and San Antonio the giving the least profit

# %%
top_states_s = supstr.groupby("State").Sales.sum().nlargest(n=10)
top_states_p = supstr.groupby("State").Profit.sum().nlargest(n = 10)
plt.style.use('seaborn')
top_states_s.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_states_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14, color = 'red')
plt.xlabel('States',fontsize = 15)
plt.ylabel('Total sales',fontsize = 15)
plt.title("Top 10 states Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# ### Customer Analysis

# %%
# To check maximum Sales and Profit in each segment
sns.set(style="dark")
supstr.groupby(['Segment'])['Sales','Profit'].sum().plot.bar(color=['#375788','#378869'],figsize=(12,6))
plt.xlabel("SEGMENT",fontdict={'color':'black','fontsize':15})
plt.title("SEGMENT WISE SALES AND PROFIT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'SEGMENT WISE SALES AND PROFIT')

# %% [markdown]
# From the above diagram we can see that Consumer segment is the one which has maximum buying capacity. Also they give maximum profit to Superstore whereas Home Office contributes the least towords sales and profit

# %%
#Checking Ship Mode Segment wise
sns.set(style='dark')
plt.subplots(figsize=(16,8))
sns.countplot(x='Segment',hue='Ship Mode',data=supstr)
plt.xlabel('SEGMENT',fontdict={'color':'black','fontsize':15})
plt.title("SEGMENT WISE SHIP MODE",fontdict={'color':'black','fontsize':15})
# Out:
# Text(0.5, 1.0, 'SEGMENT WISE SHIP MODE')

# %% [markdown]
# Most of the transaction has been shipped under Standard Class

# %%
plt.style.use('seaborn')
supstr.plot(kind = "scatter",figsize = (10,5), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap = "viridis")
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Interdependency of Sales,Profits and Discounts",fontsize = 16)
plt.show()

# %%
sns.set(style='dark')
plt.subplots(figsize=(12,6))
sns.regplot(x=supstr['Sales'],y=supstr['Profit'],color='red',line_kws={'color':'blue'})
plt.xlabel("SALES",fontdict={'color':'black','fontsize':15})
plt.ylabel("PROFIT",fontdict={'color':'black','fontsize':15})
plt.title("RELATIONSHIP BETWEEN SALES AND PROFIT",fontdict={'color':'black','fontsize':20})
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP BETWEEN SALES AND PROFIT')

# %% [markdown]
# Again from the scatterplot we see that there is a positively sloped trendline which concludes a strong positive relationship between Sales and Profit.

# %% [markdown]
# **The graph clearly shows that if we giive more Discount on our products sales increases but profit decreases.**

# %% [markdown]
# ## Conclusions

# %% [markdown]
# #### 1.MAXIMUM TRANSACTIONS were made in WEST REGION
# ##### 2.MAXIMUM SALES in WEST REGION
# ##### 3.MAXIMUM PROFITS in WEST REGION
# ##### 4.MAXIMUM SALES AND PROFIT in CONSUMER SEGMENT
# ##### 5.MAXIMUM TRANSACTIONS were shipped in STANDARD CLASS irrespective of SEGMENT
# ##### 6.LEAST PROFIT is incurred in FURNITURE CATEGORY irrespective of good amount of Sales
# ##### 7.Under FURNITURE, TABLES and BOOKCASES are INCURRING LOSSES which is effecting the TOTAL PROFIT of Furniture Category
# ##### 8.HIGH DISCOUNT is being offered in TABLES and BOOKCASES which is somewhere the probable reason of losses.
# ##### 9. City Contributing to the maximum profit and sales is NEW YORK City
# ##### 10. Maximum discount is given in the city  of Philadelphia
# ##### 11. Philadelphia contributes least towards profit
# ##### 12.POSITIVE CORRELATION:Profit and Sales
# ##### 13.NEGATIVE CORRELATION:Profit and Discount
# ##### 14.LESS the DISCOUNT ,MORE the PROFIT and vice-versa

# %% [markdown]
# **Some Solutions:**
#
# To increase profit we can:
#
# 1.   The sub-categories sales of tables should be minimized.
# 2.   Increase sales more in the east as the profit is more.
# 3.   States like 'New York' and 'California' can give more profit

# %% [markdown]
# ##### From Above Observation we conclude that FURNITURE CATEGORY is the WEAK AREA where we need to work upon. As in Furniture we have TABLES and BOOKCASES where due to HIGH DISCOUNT offered we are incurring LOSSES. So we need to REDUCE the DISCOUNT in order to INCREASE the PROFIT.
#
# ##### Maximum discounts are given to Philadelphia followed by Houston and Chicago.Despite this fact Philadelphia is contributing the least towards profit followed by Houston so we can reduce the discounts given to this cities.
